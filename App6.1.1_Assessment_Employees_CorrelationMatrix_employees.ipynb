# %%
# Define the directory structure using file.path()
my_dir <- file.path("C:/Users/GPEL_HPENVY/Desktop/Project_Predictive_Analytics_R")

# Check if the directory exists
if (dir.exists(my_dir)) {
  # Set the working directory
  setwd(my_dir)
  cat("Working directory set to:", getwd(), "\n")
} else {
  cat("Directory does not exist:", my_dir, "\n")
}
# Out:
# Working directory set to: C:/Users/GPEL_HPENVY/Desktop/Project_Predictive_Analytics_R

# %%
# set file path
# read csv file
#setwd('H:/GPEL_HPENVY/Documents/UNSW/07_ZZBU6511/Assessment3/')
employees <- read.csv(file = 'employees2.csv')

# Modify the column names to remove unwanted characters (assuming the problematic column is named "ï..Age")
colnames(employees) <- gsub("ï\\.{2}", "", colnames(employees))

# %%
# Inspect file
head(employees)
# Out:
#   Age Attrition BusinessTravel    Department             DistanceFromHome
# 1 26  No        Travel_Frequently Research & Development 10
# 2 33  No        Travel_Rarely     Research & Development 13
# 3 59  No        Travel_Rarely     Research & Development  5
# 4 42  No        Travel_Rarely     Research & Development 21
# 5 24  No        Travel_Rarely     Research & Development 27
# 6 29  No        Travel_Rarely     Research & Development 37
#   Education EnvironmentSatisfaction Gender JobInvolvement
# 1 3         3                       Male   4
# 2 5         4                       Male   3
# 3 3         3                       Female 4
# 4 3         2                       Male   4
# 5 1         4                       Female 2
# 6 2         3                       Male   4
#   JobRole                   ... RelationshipSatisfaction StockOptionLevel
# 1 Laboratory Technician     ... 1                        1
# 2 Healthcare Representative ... 1                        0
# 3 Laboratory Technician     ... 1                        3
# 4 Healthcare Representative ... 3                        2
# 5 Manufacturing Director    ... 2                        2
# 6 Research Scientist        ... 3                        1
#   TotalWorkingYears TrainingTimesLastYear WorkLifeBalance YearsAtCompany
# 1  8                3                     3                7
# 2 14                6                     3                0
# 3 12                3                     2                1
# 4 10                2                     2                0
# 5  5                6                     3                4
# 6 10                3                     3               10
#   YearsInCurrentRole YearsSinceLastPromotion YearsWithCurrManager
# 1 7                  7                       7
# 2 0                  0                       0
# 3 0                  0                       0
# 4 0                  0                       0
# 5 2                  3                       2
# 6 7                  0                       7
#   HighPerformance
# 1 0
# 2 0
# 3 1
# 4 0
# 5 0
# 6 1

# %%
# Add new binary variables to the employees data frame
employees$Is.Attrition = ifelse(employees$Attrition == "Yes", 1, 0)
employees$Is.OverTime = ifelse(employees$OverTime == "Yes", 1, 0)
employees$Is.Male = ifelse(employees$Gender == "Male", 1, 0)
employees$Is.BusNonTravel = ifelse(employees$BusinessTravel == "Non-Travel", 1, 0)
employees$Is.BusTravelRare = ifelse(employees$BusinessTravel == "Travel_Rarely", 1, 0)
employees$Is.BusTravelFreq = ifelse(employees$BusinessTravel == "Travel_Frequently", 1, 0)

# %%
# List all the column names
column_names <- colnames(employees)
print(column_names)
# Out:
#  [1] "Age"                      "Attrition"
#  [3] "BusinessTravel"           "Department"
#  [5] "DistanceFromHome"         "Education"
#  [7] "EnvironmentSatisfaction"  "Gender"
#  [9] "JobInvolvement"           "JobRole"
# [11] "JobSatisfaction"          "MaritalStatus"
# [13] "MonthlyIncome"            "NumCompaniesWorked"
# [15] "Over18"                   "OverTime"
# [17] "SalaryIncrease"           "RelationshipSatisfaction"
# [19] "StockOptionLevel"         "TotalWorkingYears"
# [21] "TrainingTimesLastYear"    "WorkLifeBalance"
# [23] "YearsAtCompany"           "YearsInCurrentRole"
# [25] "YearsSinceLastPromotion"  "YearsWithCurrManager"
# [27] "HighPerformance"          "Is.Attrition"
# [29] "Is.OverTime"              "Is.Male"
# [31] "Is.BusNonTravel"          "Is.BusTravelRare"
# [33] "Is.BusTravelFreq"

# %%
# Inspect file
head(employees)
# Out:
#   Age Attrition BusinessTravel    Department             DistanceFromHome
# 1 26  No        Travel_Frequently Research & Development 10
# 2 33  No        Travel_Rarely     Research & Development 13
# 3 59  No        Travel_Rarely     Research & Development  5
# 4 42  No        Travel_Rarely     Research & Development 21
# 5 24  No        Travel_Rarely     Research & Development 27
# 6 29  No        Travel_Rarely     Research & Development 37
#   Education EnvironmentSatisfaction Gender JobInvolvement
# 1 3         3                       Male   4
# 2 5         4                       Male   3
# 3 3         3                       Female 4
# 4 3         2                       Male   4
# 5 1         4                       Female 2
# 6 2         3                       Male   4
#   JobRole                   ... YearsInCurrentRole YearsSinceLastPromotion
# 1 Laboratory Technician     ... 7                  7
# 2 Healthcare Representative ... 0                  0
# 3 Laboratory Technician     ... 0                  0
# 4 Healthcare Representative ... 0                  0
# 5 Manufacturing Director    ... 2                  3
# 6 Research Scientist        ... 7                  0
#   YearsWithCurrManager HighPerformance Is.Attrition Is.OverTime Is.Male
# 1 7                    0               0            0           1
# 2 0                    0               0            1           1
# 3 0                    1               0            1           0
# 4 0                    0               0            0           1
# 5 2                    0               0            0           0
# 6 7                    1               0            0           1
#   Is.BusNonTravel Is.BusTravelRare Is.BusTravelFreq
# 1 0               0                1
# 2 0               1                0
# 3 0               1                0
# 4 0               1                0
# 5 0               1                0
# 6 0               1                0

# %%
# Create group of the numeric variables only
select_employees <- employees[c(
  "Is.Attrition", "Is.OverTime", "Age", "DistanceFromHome", "Education", "EnvironmentSatisfaction",
  "Is.Male", "JobInvolvement", "JobSatisfaction", "MonthlyIncome", "NumCompaniesWorked",
  "SalaryIncrease", "RelationshipSatisfaction", "StockOptionLevel", "Is.BusNonTravel", "Is.BusTravelRare",
  "Is.BusTravelFreq", "TotalWorkingYears", "TrainingTimesLastYear", "WorkLifeBalance",
  "YearsAtCompany", "YearsInCurrentRole", "YearsSinceLastPromotion",
  "YearsWithCurrManager", "HighPerformance"
  )]

# Calculate Correlation
cor_values <- cor(select_employees)

# Print the correlation values
cor_values
# Out:
#                          Is.Attrition Is.OverTime  Age
# Is.Attrition              1.00000000   0.248287942 -0.1252460256
# Is.OverTime               0.24828794   1.000000000  0.0732782380
# Age                      -0.12524603   0.073278238  1.0000000000
# DistanceFromHome          0.06853966   0.033928250 -0.0046064255
# Education                -0.03240088  -0.024587437  0.2073061401
# EnvironmentSatisfaction  -0.11000079   0.075354171  0.0138926478
# Is.Male                   0.05812382  -0.037807847 -0.0395284196
# JobInvolvement           -0.12761514  -0.001380718  0.0408753568
# JobSatisfaction          -0.11852944   0.042260363  0.0004968495
# MonthlyIncome            -0.13906874   0.044829235  0.5246913526
# NumCompaniesWorked        0.04222253   0.006589270  0.3117103563
# SalaryIncrease           -0.01830161  -0.019988654 -0.0027323938
# RelationshipSatisfaction -0.01284565   0.085856256  0.0254509927
# StockOptionLevel         -0.11564358   0.006865293  0.0405914614
# Is.BusNonTravel          -0.08605767  -0.026919221 -0.0037535158
# Is.BusTravelRare         -0.03587044  -0.020005708  0.0209681462
# Is.BusTravelFreq          0.10868089   0.044219913 -0.0214826268
# TotalWorkingYears        -0.15558427   0.031516263  0.6976502536
# TrainingTimesLastYear    -0.02396388  -0.081224394 -0.0325330238
# WorkLifeBalance          -0.09327154  -0.032677390 -0.0198595530
# YearsAtCompany           -0.12875680  -0.015880907  0.3040188154
# YearsInCurrentRole       -0.15857383  -0.061905699  0.2040732475
# YearsSinceLastPromotion  -0.03647379  -0.004623128  0.2189379588
# YearsWithCurrManager     -0.15410180  -0.067015316  0.1919497239
# HighPerformance          -0.01193199  -0.043522692  0.0024286362
#                          DistanceFromHome Education    EnvironmentSatisfaction
# Is.Attrition              0.068539664     -0.032400880 -0.1100007919
# Is.OverTime               0.033928250     -0.024587437  0.0753541715
# Age                      -0.004606425      0.207306140  0.0138926478
# DistanceFromHome          1.000000000     -0.017935578 -0.0174285703
# Education                -0.017935578      1.000000000 -0.0018959087
# EnvironmentSatisfaction  -0.017428570     -0.001895909  1.0000000000
# Is.Male                  -0.019207099      0.004181482 -0.0107902431
# JobInvolvement           -0.019933278      0.058535519 -0.0046379010
# JobSatisfaction          -0.027065654     -0.017633771 -0.0274835379
# MonthlyIncome            -0.036166144      0.084308015  0.0230662676
# NumCompaniesWorked       -0.019552529      0.138049902  0.0146823006
# SalaryIncrease            0.038368069      0.006601899 -0.0529714724
# RelationshipSatisfaction -0.006331329     -0.003866672  0.0104878913
# StockOptionLevel          0.062709933      0.022452038 -0.0077670004
# Is.BusNonTravel           0.039991254      0.029078666 -0.0001573109
# Is.BusTravelRare         -0.001091079     -0.011570712  0.0345500441
# Is.BusTravelFreq         -0.029835549     -0.009151811 -0.0400859858
# TotalWorkingYears        -0.004784776      0.156482136  0.0167584931
# TrainingTimesLastYear    -0.043959516     -0.027138326 -0.0279074907
# WorkLifeBalance          -0.030897569      0.009861590  0.0643305328
# YearsAtCompany           -0.004006397      0.047645461  0.0047291395
# YearsInCurrentRole        0.003945215      0.054771988  0.0203115387
# YearsSinceLastPromotion  -0.005770798      0.056411897  0.0089846618
# YearsWithCurrManager      0.023812180      0.037196099 -0.0145139571
# HighPerformance           0.016377219      0.002199158 -0.0553219146
#                          Is.Male      JobInvolvement JobSatisfaction
# Is.Attrition              0.058123819 -0.1276151350  -0.1185294408
# Is.OverTime              -0.037807847 -0.0013807182   0.0422603626
# Age                      -0.039528420  0.0408753568   0.0004968495
# DistanceFromHome         -0.019207099 -0.0199332778  -0.0270656537
# Education                 0.004181482  0.0585355185  -0.0176337712
# EnvironmentSatisfaction  -0.010790243 -0.0046379010  -0.0274835379
# Is.Male                   1.000000000  0.0124913988   0.0163715465
# JobInvolvement            0.012491399  1.0000000000  -0.0273785421
# JobSatisfaction           0.016371546 -0.0273785421   1.0000000000
# MonthlyIncome            -0.016953144 -0.0189711393  -0.0015835378
# NumCompaniesWorked       -0.053885409  0.0187124627  -0.0506693179
# SalaryIncrease           -0.008655735  0.0091208389   0.0236390760
# RelationshipSatisfaction  0.026215289  0.0385821876  -0.0130642842
# StockOptionLevel          0.010034866 -0.0157753459   0.0058984793
# Is.BusNonTravel           0.044480157 -0.0270090175   0.0106461697
# Is.BusTravelRare         -0.038211675  0.0046671873  -0.0417272231
# Is.BusTravelFreq          0.009872846  0.0155761556   0.0402803140
# TotalWorkingYears        -0.032851383 -0.0066156387  -0.0060431639
# TrainingTimesLastYear    -0.010878271  0.0002294698  -0.0151606843
# WorkLifeBalance           0.014257237 -0.0265264114  -0.0141213903
# YearsAtCompany           -0.025716395 -0.0192092403  -0.0201864308
# YearsInCurrentRole       -0.034303193 -0.0010465776   0.0042318392
# YearsSinceLastPromotion  -0.012399137 -0.0195869678  -0.0506423142
# YearsWithCurrManager     -0.020881145  0.0323179508  -0.0282615459
# HighPerformance          -0.027651832 -0.0140930629   0.0134850800
#                          MonthlyIncome ... Is.BusTravelRare Is.BusTravelFreq
# Is.Attrition             -0.139068744  ... -0.035870436      0.108680889
# Is.OverTime               0.044829235  ... -0.020005708      0.044219913
# Age                       0.524691353  ...  0.020968146     -0.021482627
# DistanceFromHome         -0.036166144  ... -0.001091079     -0.029835549
# Education                 0.084308015  ... -0.011570712     -0.009151811
# EnvironmentSatisfaction   0.023066268  ...  0.034550044     -0.040085986
# Is.Male                  -0.016953144  ... -0.038211675      0.009872846
# JobInvolvement           -0.018971139  ...  0.004667187      0.015576156
# JobSatisfaction          -0.001583538  ... -0.041727223      0.040280314
# MonthlyIncome             1.000000000  ...  0.016063967     -0.016891930
# NumCompaniesWorked        0.142445850  ...  0.046375013     -0.038696343
# SalaryIncrease           -0.068415742  ... -0.020579997      0.003620994
# RelationshipSatisfaction  0.023046596  ... -0.060685112      0.027105395
# StockOptionLevel         -0.009187235  ... -0.002645243     -0.012542310
# Is.BusNonTravel          -0.002317876  ... -0.529914338     -0.161103949
# Is.BusTravelRare          0.016063967  ...  1.000000000     -0.751602165
# Is.BusTravelFreq         -0.016891930  ... -0.751602165      1.000000000
# TotalWorkingYears         0.780749485  ... -0.009499327      0.011626077
# TrainingTimesLastYear    -0.032123075  ...  0.025062780     -0.018671395
# WorkLifeBalance           0.025863303  ...  0.024016496     -0.018196714
# YearsAtCompany            0.521392360  ... -0.075570092      0.062581450
# YearsInCurrentRole        0.363213412  ... -0.035193146      0.011785369
# YearsSinceLastPromotion   0.367705007  ... -0.055349144      0.051731423
# YearsWithCurrManager      0.350698652  ... -0.068960803      0.041919421
# HighPerformance          -0.056154699  ... -0.029039646      0.026830124
#                          TotalWorkingYears TrainingTimesLastYear
# Is.Attrition             -0.1555842696     -0.0239638838
# Is.OverTime               0.0315162628     -0.0812243937
# Age                       0.6976502536     -0.0325330238
# DistanceFromHome         -0.0047847757     -0.0439595161
# Education                 0.1564821364     -0.0271383261
# EnvironmentSatisfaction   0.0167584931     -0.0279074907
# Is.Male                  -0.0328513827     -0.0108782709
# JobInvolvement           -0.0066156387      0.0002294698
# JobSatisfaction          -0.0060431639     -0.0151606843
# MonthlyIncome             0.7807494851     -0.0321230746
# NumCompaniesWorked        0.2531434227     -0.0875873445
# SalaryIncrease           -0.0333488379     -0.0082769798
# RelationshipSatisfaction  0.0116198501     -0.0130100092
# StockOptionLevel         -0.0074244673     -0.0164627530
# Is.BusNonTravel          -0.0007341648     -0.0134943476
# Is.BusTravelRare         -0.0094993268      0.0250627796
# Is.BusTravelFreq          0.0116260775     -0.0186713953
# TotalWorkingYears         1.0000000000     -0.0455484784
# TrainingTimesLastYear    -0.0455484784      1.0000000000
# WorkLifeBalance          -0.0059698017      0.0224242647
# YearsAtCompany            0.6105410592     -0.0006038642
# YearsInCurrentRole        0.4459286239     -0.0063153659
# YearsSinceLastPromotion   0.4106215094      0.0205154077
# YearsWithCurrManager      0.4453125705     -0.0138260848
# HighPerformance          -0.0045820519      0.0200957586
#                          WorkLifeBalance YearsAtCompany YearsInCurrentRole
# Is.Attrition             -0.093271536    -0.1287567969  -0.158573830
# Is.OverTime              -0.032677390    -0.0158809065  -0.061905699
# Age                      -0.019859553     0.3040188154   0.204073248
# DistanceFromHome         -0.030897569    -0.0040063975   0.003945215
# Education                 0.009861590     0.0476454608   0.054771988
# EnvironmentSatisfaction   0.064330533     0.0047291395   0.020311539
# Is.Male                   0.014257237    -0.0257163951  -0.034303193
# JobInvolvement           -0.026526411    -0.0192092403  -0.001046578
# JobSatisfaction          -0.014121390    -0.0201864308   0.004231839
# MonthlyIncome             0.025863303     0.5213923595   0.363213412
# NumCompaniesWorked        0.001172563    -0.1086607426  -0.084483879
# SalaryIncrease           -0.029180366    -0.0463948241  -0.006289447
# RelationshipSatisfaction  0.001566401     0.0103861646  -0.045343021
# StockOptionLevel         -0.030093123     0.0001403388   0.037229099
# Is.BusNonTravel          -0.012539153     0.0326108804   0.037504869
# Is.BusTravelRare          0.024016496    -0.0755700922  -0.035193146
# Is.BusTravelFreq         -0.018196714     0.0625814503   0.011785369
# TotalWorkingYears        -0.005969802     0.6105410592   0.445928624
# TrainingTimesLastYear     0.022424265    -0.0006038642  -0.006315366
# WorkLifeBalance           1.000000000    -0.0091503362   0.034415605
# YearsAtCompany           -0.009150336     1.0000000000   0.764421344
# YearsInCurrentRole        0.034415605     0.7644213437   1.000000000
# YearsSinceLastPromotion  -0.010433122     0.6426022272   0.559589273
# YearsWithCurrManager     -0.009311480     0.7715706628   0.731491311
# HighPerformance          -0.002437489    -0.0024679484   0.036323190
#                          YearsSinceLastPromotion YearsWithCurrManager
# Is.Attrition             -0.036473786            -0.154101802
# Is.OverTime              -0.004623128            -0.067015316
# Age                       0.218937959             0.191949724
# DistanceFromHome         -0.005770798             0.023812180
# Education                 0.056411897             0.037196099
# EnvironmentSatisfaction   0.008984662            -0.014513957
# Is.Male                  -0.012399137            -0.020881145
# JobInvolvement           -0.019586968             0.032317951
# JobSatisfaction          -0.050642314            -0.028261546
# MonthlyIncome             0.367705007             0.350698652
# NumCompaniesWorked       -0.029975709            -0.092588793
# SalaryIncrease           -0.035486517             0.001212752
# RelationshipSatisfaction  0.035721531            -0.015553205
# StockOptionLevel          0.018151982             0.015323250
# Is.BusNonTravel           0.016305301             0.049286478
# Is.BusTravelRare         -0.055349144            -0.068960803
# Is.BusTravelFreq          0.051731423             0.041919421
# TotalWorkingYears         0.410621509             0.445312570
# TrainingTimesLastYear     0.020515408            -0.013826085
# WorkLifeBalance          -0.010433122            -0.009311480
# YearsAtCompany            0.642602227             0.771570663
# YearsInCurrentRole        0.559589273             0.731491311
# YearsSinceLastPromotion   1.000000000             0.525002008
# YearsWithCurrManager      0.525002008             1.000000000
# HighPerformance           0.007133985             0.036116132
#                          HighPerformance
# Is.Attrition             -0.011931993
# Is.OverTime              -0.043522692
# Age                       0.002428636
# DistanceFromHome          0.016377219
# Education                 0.002199158
# EnvironmentSatisfaction  -0.055321915
# Is.Male                  -0.027651832
# JobInvolvement           -0.014093063
# JobSatisfaction           0.013485080
# MonthlyIncome            -0.056154699
# NumCompaniesWorked       -0.015511607
# SalaryIncrease            0.769506889
# RelationshipSatisfaction -0.043150045
# StockOptionLevel          0.035646195
# Is.BusNonTravel           0.008955195
# Is.BusTravelRare         -0.029039646
# Is.BusTravelFreq          0.026830124
# TotalWorkingYears        -0.004582052
# TrainingTimesLastYear     0.020095759
# WorkLifeBalance          -0.002437489
# YearsAtCompany           -0.002467948
# YearsInCurrentRole        0.036323190
# YearsSinceLastPromotion   0.007133985
# YearsWithCurrManager      0.036116132
# HighPerformance           1.000000000

# %%
# Create group of the numeric variables only
select_employees <- employees[c(
  "Is.Attrition", "Is.OverTime", "Age"
  )]

# Calculate Correlation
cor_values <- cor(select_employees)

# Print the correlation values
cor_values
# Out:
#              Is.Attrition Is.OverTime Age
# Is.Attrition  1.0000000   0.24828794  -0.12524603
# Is.OverTime   0.2482879   1.00000000   0.07327824
# Age          -0.1252460   0.07327824   1.00000000
